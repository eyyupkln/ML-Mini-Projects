# %%
import  numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from xgboost import XGBClassifier

# %%
df=pd.read_csv("creditcard.zip")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
print('No Frauds', round(df['Class'].value_counts()[0] / len(df) * 100, 2), '% of the dataset')
print('Frauds', round(df['Class'].value_counts()[1] / len(df) * 100, 2), '% of the dataset')
# Out:
# No Frauds 99.83 % of the dataset
# Frauds 0.17 % of the dataset

# %%
# it an unbalanced data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().values.sum()
# Out:
# 0

# %%
sns.countplot(data=df, x="Class")
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,4))

amount_val = df['Amount'].values
time_val = df['Time'].values

sns.distplot(amount_val, ax=ax[0], color='r')
ax[0].set_title('Distribution of Transaction Amount', fontsize=14)
ax[0].set_xlim([min(amount_val), max(amount_val)])

sns.distplot(time_val, ax=ax[1], color='b')
ax[1].set_title('Distribution of Transaction Time', fontsize=14)
ax[1].set_xlim([min(time_val), max(time_val)])

plt.show()

# %%
X=df.drop('Class',axis=1)
y=df['Class']

# %%
from sklearn.ensemble import IsolationForest
iso = IsolationForest (
     n_estimators=200,
    contamination=0.001727, #it is percentage of contamination ratio
    max_samples="auto",
    max_features=1.0,
    random_state=42,
    n_jobs=-1
)

# %%
iso.fit(X)
# Out:
# IsolationForest(contamination=0.001727, n_estimators=200, n_jobs=-1,
#                 random_state=42)

# %%
df["iso_raw"] = iso.predict(X)

# %%
df['iso_raw'].unique()
# Out:
# array([ 1, -1])

# %%
#1  → normal
#-1 → anomaly

# %%
df["iso_pred"] = df["iso_raw"].map({1:0, -1:1})

# %%
df["iso_pred"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
X = df.drop(["Class","iso_raw","iso_pred"], axis=1)
y = df["Class"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    stratify=y,   # it will be important for isolation forest.
    random_state=42
)

# %%
iso_test_pred = df.loc[X_test.index, "iso_pred"]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, iso_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.24      0.24      0.24       148
#
#     accuracy                           1.00     85443
#    macro avg       0.62      0.62      0.62     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
df["Iso_Score"] = iso.decision_function(X)

# %%
sns.kdeplot(
    df[df["Class"]==0]["Iso_Score"],
    label="Normal"
)

sns.kdeplot(
    df[df["Class"]==1]["Iso_Score"],
    label="Fraud"
)

plt.legend()
plt.title("Anomaly Score Distribution")
plt.show()

# %%
train_anomaly_scores = iso.decision_function(X_train)
test_anomaly_scores = iso.decision_function(X_test)

# %%
X_train_hybrid = X_train.copy()
X_test_hybrid = X_test.copy()

# %%
X_train_hybrid['Iso_Score'] = train_anomaly_scores
X_test_hybrid['Iso_Score'] = test_anomaly_scores

# %%
df2 = pd.concat([X_train_hybrid, X_test_hybrid])

# %%
df2['Class'] = df.loc[df2.index, 'Class']

# %%
sns.kdeplot(
    df2[df2["Class"]==0]["Iso_Score"],
    label="Normal"
)

sns.kdeplot(
    df2[df2["Class"]==1]["Iso_Score"],
    label="Fraud"
)

plt.legend()
plt.title("Anomaly Score Distribution")
plt.show()

# %%
# let's see top 1% suspicious transaction

# %%
threshold= df2["Iso_Score"].quantile(0.01)

# %%
df2["iso_custom"] = (df2["Iso_Score"] < threshold).astype(int)

# %%
print(classification_report(df2["Class"], df2["iso_custom"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    284315
#            1       0.10      0.58      0.17       492
#
#     accuracy                           0.99    284807
#    macro avg       0.55      0.79      0.58    284807
# weighted avg       1.00      0.99      0.99    284807

# %%
# recall increased.

# %%
df_sorted = df2.sort_values("Iso_Score")

# %%
k = int(len(df_sorted) * 0.01)

top_k = df_sorted.head(k)

# %%
frauds_captured = top_k["Class"].sum()
total_frauds = df2["Class"].sum()

recall_at_k = frauds_captured / total_frauds

print(recall_at_k)
# Out:
# 0.5792682926829268

# %%
percentages=np.linspace(0.001,0.05,30)
recall=[]
for per in percentages :
    k = int(len(df_sorted) * per)
    captured = df_sorted.head(k)["Class"].sum()
    recall.append(captured / total_frauds)

# %%
plt.plot(percentages * 100 , recall)
plt.xlabel("investigated transaction")
plt.ylabel("fraud recall")
plt.title("Top-K Capture Curve (Isolation Forest)")

plt.show()

# %%
from xgboost import XGBClassifier
print("Training with XGBoostClassifier...")
# Out:
# Training with XGBoostClassifier...

# %%
X = df2.drop(["Class", "Iso_Score", "iso_custom"], axis=1)
# anomaly_score is already in X

y = df2["Class"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

xgb = XGBClassifier(
    scale_pos_weight=len(y_train[y_train==0]) / len(y_train[y_train==1]),
    random_state=42, n_jobs=-1
)
#scale_pos_weight to handle unbalanced dataset

xgb.fit(X_train, y_train)
print(classification_report(y_test, xgb.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.89      0.79      0.84       148
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.90      0.92     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
# now we can see recall increased 0.79 . it is a good situation for this dataset.

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, xgb.predict(X_test))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds')
plt.title("Hybrit Model")
plt.ylabel('Actual values')
plt.xlabel('Predicted values')
plt.show()
